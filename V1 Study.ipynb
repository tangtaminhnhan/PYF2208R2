# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
class SoHoc:

    def inputinfo(self):
        self.number1 = int(input("nhap1"))
        self.number2 = int(input("nhap2"))
    def printinfo(self):
        print(self.number1)
        print(self.number2)
    def addition(self):
        print(self.number1 + self.number2)
    def subtract(self):
        print(abs(self.number1 - self.number2))
    def multi(self):
        print(self.number1 * self.number2)
    def divison(self):
        print(self.number1  / self.number2)
a= SoHoc()

# %%
import tkinter as tk

window = tk.Tk()
window.title("Grid")

for i in range(5):
    for j in range(3):
        frame = tk.Frame(
            master = window,
            relief = tk.RAISED,
            borderwidth = 1
        )
        frame.grid(row=i, column=j)
        label = tk.Label(master=frame, text=f"Row {i}\nColumn {j}")
        label.pack()

window.mainloop()

# %%
class Battery:
    energy = ""
    def __init__(self, energy = 10):
        self.energy = energy
    def setEnergy(self, energy_1):
        self.energy = energy_1
    def getEnergy(self):
        print(f"gia tri nang luong la:{self.energy}")
    def decreaseEnergy(self):
        self.energy -= 2
        if self.energy < 0 :
            self.energy = 0
class FlashLamp(Battery):
    status = ""
    battery = Battery()
    def __init__(self):
        self.status = False
        self.battery = Battery()
    def setBattery(self):
        energy_2 = int(input("nap pin cho den"))
        self.battery.setEnergy(energy_2)
    def getBattery(self):
        self.battery.getEnergy()
    def turnOn(self):
        self.status = True
        self.battery.decreaseEnergy()
        if self.energy > 0:
            print("den sang")
        else:
            print("den ko sang")
        
    def turnOff(self):
        self.status = False
        print("den tat")
class TestFlash:
    def main(self):
    a = Battery()
    b = FlashLamp()
    b.setBattery()
    for i in range(10):
        b.turnOn()
        b.turnOff()
        if a.energy == 0:
            break
    a.getEnergy()
TestFlash.main()

# %%
class SoNguyenTo:
    def __init__(self,x):
        for i in range(2,x//2):
            if x % i == 0:
                print(" x k la so nguyen to")
                break
            if i == x//2 :
                self.a = x
    def isSoNguyenTo(self, x):
        for i in range(2, x)

# %%
class tamgiac:
    def __init__(self,a,b,c):
        self.a = a
        self.b = b
        self.c = c
    def typetamgiac(self):
        if a == b or a == c or b == c:
            if a == b == c:
                return "tam giac deu"
            else:
                return "tam giac can"
        elif a**2 + b**2 == c**2 or a**2 + c**2 == b**2 or c**2 + b**2 == a**2:
            return "tam giac vuong"
        else:
            return "tam giac thuong"
    def chuvi(self):
        return self.a + self.b + self.c
    def dientich(self):
        n = tamgiac()
        p = (n.chuvi())/2
        return (p * (p - a) * (p - b) * (p - c))**0.5
a = tamgiac()

# %%
import math
class MyCircle:
    def __init__(self, x = 0, y = 0):
        self.x = x
        self.y = y
    def toString(self):
        print(f"({self.x},{self.y})")
    def distance(self, x, y):
        x_cach = self.x - x
        y_cach = self.y - y
        return math.sqrt(x_cach ** 2 + y_cach **2)
    def distance(self, another):
        x_cach = self.x - another.x
        y_cach = self.x - another.y
        return math.sqrt(x_cach ** 2 + y_cach ** 2)
a = MyCircle(2,2)
b = MyCircle(5,5)
a.distance(2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [23], line 18
#      16 a = MyCircle(2,2)
#      17 b = MyCircle(5,5)
# ---> 18 a.distance(2,3)
#
# TypeError: MyCircle.distance() takes 2 positional arguments but 3 were given

# %%
class complex: 
    def __init__(self, a, b): 
        self.a = a 
        self.b = b 
  
     # adding two objects  
    def __add__(self, other): 
        return self.a + other.a, self.b + other.b 
  
    def __str__(self): 
        return self.a, self.b 
  
Ob1 = complex(1, 2) 
Ob2 = complex(2, 3) 
Ob3 = Ob1 + Ob2 
str(Ob3)
# Out:
# '(3, 5)'

# %%
class Product:
    list_race = []
    def __init__(self,Name = 0, Description = 0, Price = 0):
        self.Name = Name
        self.Description = Description
        if 0< Price <=100 :
            self.Price = Price
        else:
            self.Price = None
    def viewInfo(self):
        return f"ten:{self.name}\tgia:{self.Price}\tdanh gia:{self.Description}"
class Shop():
    List_ProductList = []
    def addProduct(self):
        Name = input("nhap ten:")
        Description = input("nhap danhgia:")
        Price = float(input("nhap tien:"))
        Rate = int(input("nhap danh gia"))
        List__ProductList.append([Name,Description,Price,Rate])
    def removeProduct(self):
        name = input("nhap ten san pham")
        for i in range(len(List_ProductList)):
            if List_ProductList[i][0] == name:
                List_ProductList.pop(i)
                break
    def iterateProductList(self):
        count_rate = 0
        for i in range(len(List_ProductList)):
            a = Product(List_ProductList[i][0],List_ProductList[i][1],List_ProductList[i][2])
            a.viewInfo()
            count_rate += List_ProductList[i][3]
            if i == len(List_ProductList) - 1 :
                return  f"rate = {count_rate / i}"
    def searchProduct(self):
        n_1 = int(input("nhap vao so thu 1:"))
        n_2 = int(input("nhap vao so thu 2:"))
        for i in range(n_1, n_2 + 1):
            print(f"ten:{List_ProductList[i][0]}\tgia:{List_ProductList[i][1]}\tdanh gia:{List_ProductList[i][2]}\trate:{List_ProductList[i][0]}")
class Menu:
    def main(self):
        check2 = Shop()
        check1 = Product()
        n = int(input("nhap "))
        if n == 1:
            check2.addProduct()
        elif n == 2:
            check2.removeProduct()
        elif n == 3:
            check2.iterateProductList()
        elif n == 4:
            check2.searchProduct()
        else:
            print("exit")
Menu().main()

# %%
class BankAccount:
    def BankAccount(self, accountName, accountNumber):
        self.accountName = accountName
        self.accountNumber = accountNumber
        self.balance = 0
    def getAccountNumber(self):
        return f"ten : {self.accountName}"
    
    def getAccountName(self):
        return f"so tai khoan : {self.accountNumber}"
    
    def getBalance(self):
        return f"tien :{self.balance}"
    
    def deposit(self, money):
        self.balance = money
    
    def withdraw(self, money):
        if money <= self.balance:
            self.balance -= money
            return True
        else:
            return False
class Bank(BankAccount):
    BankAccount = []
    
    def search(self, accountNumber):
        for i in range(len(BankAccount)):
            if BankAccount[i][1] == accountNumber:
                return BankAccount [2]
            else:
                return -1
    
    def getToTal(self):
        return len(BankAccount)
    
    def getltem(self, accountNumber):
        return 0
    
    def addAccount(self, accountNumber, accountName):
        for i in range(len(BankAccount)):
            if BankAccount[i][0] == accountName and BankAccount[i][1] == accountNumber:
                return False
        BankAccount.append([accountName, accountNumber, 0])
    
    def depositMoney(self, accountNumber, money):
        for i in range(len(BankAccount)):
            if BankAccount[i][1] == accountNumber:
                BankAccount[i][2] += money
                return True
        return False
    
    def withdrawMoney(self, accountNumber, money):
        for i in range(len(BankAccount)):
            if BankAccount[i][1] == accountNumber:
                BankAccount[i][2] -= money
                return True
        return False
    
    def removeAccount(self, accountNumber):
        for i in range(len(BankAccount)):
            if BankAccount[i][1] == accountNumber:
                BankAccount.pop(i)
                return True
        return False

class quanlynganhang:
    def main(self):
        a = BankAccount()
        b = Bank()
        n = int(input("nhap vao so:"))
        if n == 1:
            check = False
            while check == False:
                add1 = int(input("nhap so tai khoan"))
                add2 =input("nhap ten tai khoan")
                add3 = float(input("nhapvao so tien"))
                b.addAccount(add1, add2)
                b.depositMoney(add1, add3)
                add4 = int(input("tiep tuc (0)/dung(1)"))
                if add4 == 1:
                    check = True
        elif n == 2:
        elif n == 3:
            for i in range(b.getToTal):
# Out:
#   Cell In [11], line 61
#     for i in range(len(BankAccount)):
#                                      ^
# SyntaxError: incomplete input

# %%
from tkinter import*
room = Tk()
room.title("xu ly nhiet do")
room.geometry("300x250")
label1 = Label(room, text = "S = ").grid(column = 0, row = 0)
label2 = Label(room, text = "v = ").grid(column = 0, row = 1)
entry1 = Entry(room)
entry1.grid(column = 1, row = 0)
entry2 = Entry(room)
entry2.grid(column = 1, row = 1)
label3 = Label(room, text = "....")
label3.grid(column = 0, row = 3)
def check():
    try:
        s = float(entry1.get())
        v = float(entry2.get())
        t = s/v
        label3.configure(text = t)
    except TypeError:
        msg = messagebox.showinfo( "ERROR", "LOI DINH DANG")
    except ZeroDivisionError:
        msg = messagebox.showinfo("ERROR", "CHIA CHO 0")
button1 = Button(room, text = "ok", command = check)
button1.grid(column = 1, row = 3)
room.mainloop()

# %%
from tkinter import *

from tkinter.ttk import *
window = Tk()
window.title("Welcome to VniTeach app")
window.geometry('350x200')

#Tạo hộp chọn Combobox
combo = Combobox(window)
#Các giá trị của hộp chọn
combo['values']= (1, 2, 3, 4, 5, "Text")
#Thiết lập giá trị được chọn
combo.current(1) #set the selected item

combo.grid(column=0, row=0)
#Lấy giá trị của hộp chọn bằng combo.get()
print(combo)
window.mainloop()
# Out:
# .!combobox

# %%
from tkinter import *

from tkinter import messagebox

top = Tk()
top.geometry("300x250")
n = Entry(top)
n.place(x=100,y=100)
def helloCallBack():
    try:
        x = int(n.get())
        print(x)
    except:
        messagebox.showinfo( "Hello Python", "no")

B = Button(top, text = "Hello", command = helloCallBack)
B.place(x = 50,y = 50)
top.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox
 
root = tk.Tk()
 
def on_closing():
    if messagebox.askokcancel("Quit", "Do you want to quit?"):
        root.destroy()
 
root.protocol("WM_DELETE_WINDOW", on_closing)
root.mainloop()

# %%
import tkinter
import tkinter.scrolledtext as scrolledtext
 
root = tkinter.Tk()
# make the top right close button minimize (iconify) the main window
root.protocol("WM_DELETE_WINDOW", root.iconify)
# make Esc exit the program
root.bind('<Escape>', lambda e: root.destroy())
 
# create a menu bar with an Exit command
menubar = tkinter.Menu(root)
filemenu = tkinter.Menu(menubar, tearoff=0)
filemenu.add_command(label="Exit", command=root.destroy)
menubar.add_cascade(label="File", menu=filemenu)
root.config(menu=menubar)
 
# create a Text widget with a Scrollbar attached
txt = scrolledtext.ScrolledText(root, undo=True)
txt['font'] = ('consolas', '12')
txt.pack(expand=True, fill='both')
 
root.mainloop()

# %%
from tkinter import*
from tkinter import messagebox
room = Tk()
room.title("My introduction")
room.geometry("300x250")
label1 = Label(room, text ="First name:")
label2 = Label(room, text ="Last name:")

entry1 = Entry(room)
entry2 = Entry(room)

def get_info():
    messagebox.showinfo("User info", f"My name is {entry1.get()} {entry2.get()}")
button = Button(room, text = "Submit", command = get_info)

label1.grid(column = 0, row = 0)
label2.grid(column = 0, row = 1)
entry1.grid(column = 1, row = 0)
entry2.grid(column = 1, row = 1)
button.grid(column = 0, row = 2)
room.mainloop()
